# %%
import random
import pandas as pd
import os

class Etoile:
    def __init__(self, coordonnees,TypeHR=None,YerkeType=None,Decimal=None,EtoileMultinaires=None,NbTellurique=None,NbGazeuse=None,NbCeintures=None,Mainworld=None,Orbit=None,Orbit_alpha=None):
        sqcPcpl=["O","B","A","F","G","K","M"]
        ponderation=[0.00003,0.13,0.6,3,7.6,12.1,76.45]
        sequenceIa=[["U","U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","U","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","U","I","I","I","I","H","O","O"]]

        sequenceIb=[["U","U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","I","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","I","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","I","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","U","I","I","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","U","U","I","I","I","I","H","O","O"]]

        sequenceII=[["U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","U","I","I","I","I","I","I","H","O","O"],
            ["U","U","I","I","I","I","I","I","H","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","I","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","I","I","I","I","I","I","H","O","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O"],
            ["U","U","U","U","U","I","I","I","I","I","H","O","O"]]

        sequenceIII=[["U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","I","I","I","I","I","I","H","O","O","O"],
            ["I","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["I","I","I","I","I","I","H","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","I","I","H","O","O","O","O","O","O"],
            ["I","I","I","I","I","I","H","O","O","O","O","O","O"],
            ["I","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["U","U","U","U","I","I","I","I","H","O","O","O","O"]]

        sequenceIV=[["U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["U","I","I","I","I","I","H","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","H","O","O","O","O","O","O","O","O"],
            ["I","I","I","I","H","O","O","O","O","O","O","O","O"],
            ["I","I","I","I","H","O","O","O","O","O","O","O","O"],
            ["I","I","I","H","O","O","O","O","O","O","O","O","O"]]

        sequenceV=[["U","U","U","U","U","U","I","I","I","I","I","H","O"],
            ["U","U","U","I","I","I","I","I","H","O","O","O","O"],
            ["I","I","I","I","I","I","I","H","O","O","O","O","O"],
            ["I","I","I","I","I","I","H","O","O","O","O","O","O"],
            ["I","I","I","I","I","H","O","O","O","O","O","O","O"],
            ["I","I","I","I","H","O","O","O","O","O","O","O","O"],
            ["I","I","I","H","O","O","O","O","O","O","O","O","O"],
            ["I","I","H","O","O","O","O","O","O","O","O","O","O"],
            ["I","I","H","O","O","O","O","O","O","O","O","O","O"],
            ["H","O","O","O","O","O","O","O","O","O","O","O","O"],
            ["H","O","O","O","O","O","O","O","O","O","O","O","O"],
            ["O","O","O","O","O","O","O","O","O","O","O","O","O"],
            ["O","O","O","O","O","O","O","O","O","O","O","O","O"]]

        sequenceVI=[["I","I","I","H","O"],
            ["I","I","H","O","O"],
            ["I","H","O","O","O"],
            ["I","H","O","O","O"],
            ["O","O","O","O","O"],
            ["O","O","O","O","O"],
            ["O","O","O","O","O"],
            ["O","O","O","O","O"]]

        sequenceD=[["H","O","O","O","O"],
           ["O","O","O","O","O"],
           ["O","O","O","O","O"],
           ["O","O","O","O","O"],
           ["O","O","O","O","O"],
           ["O","O","O","O","O"],
           ["O","O","O","O","O"]]
        
        TypeSpectral=[["Ia","Ia","Ib","II","III","III","III","V","V","V","IV","D","IV","IV","IV"],
              ["Ia","Ia","Ib","II","III","III","III","III","V","V","IV","D","IV","IV","IV"],
              ["Ia","Ia","Ib" ,"II","III","IV","V","V","V","V","V","D","V","V","V"],
              ["II","II","III","IV","V","V","V","V","V","V","VI","D","VI","VI","VI"],
              ["II","II","III","IV","V","V","V","V","V","V","VI","D","VI","VI","VI"],
              ["II","II","III","IV","V","V","V","V","V","V","VI","D","VI","VI","VI"],
              ["II","II","II","II","III","V","V","V","V","V","VI","D","VI","VI","VI"]]

        #Coordonnees
        self.coordonnees = coordonnees
        
        #Type HR
        if TypeHR == None:
            self.TypeHR= random.choices(sqcPcpl,weights = ponderation,k=1)[0]
        else:
            self.TypeHR=TypeHR
        if self.TypeHR == "O":
            print("Jackpot")
        
        #YerkeType
        if YerkeType==None:
            D1=random.randint(1,6)
            D2=random.randint(1,6)
            b=D1-D2+6
            a =0
            if self.TypeHR=="O":
                a=0
            elif self.TypeHR=="B":
                a=1
            elif self.TypeHR=="A":
                a=2
            elif self.TypeHR=="F":
                a=3
            elif self.TypeHR=="G":
                a=4
            elif self.TypeHR=="K":
                a=5
            elif self.TypeHR=="M":
                a=6
            self.YerkeType=TypeSpectral[a][b]
        else:
            self.YerkeType=YerkeType
            
        #Decimal
        if Decimal==None:
            self.Decimal=random.randint(1, 9)
        else:
            self.Decimal=Decimal
    
        
        
        #Orbit
        if Orbit==None:
            if self.YerkeType=="Ia":
                if self.TypeHR=="B" and self.Decimal in range(1,5) :
                   self.Orbit=sequenceIa[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceIa[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIa[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIa[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIa[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIa[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIa[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIa[7]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIa[8]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIa[9]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceIa[10]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceIa[11]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceIa[12]
                
            elif self.YerkeType=="Ib":
                if self.TypeHR=="B" and self.Decimal in range(1,5) :
                   self.Orbit=sequenceIb[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceIb[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIb[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIb[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIb[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIb[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIb[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIb[7]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIb[8]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIb[9]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceIb[10]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceIb[11]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceIb[12]
                
            elif self.YerkeType=="II":
                if self.TypeHR=="B" and self.Decimal in range(1,5) :
                   self.Orbit=sequenceII[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceII[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceII[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceII[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceII[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceII[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceII[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceII[7]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceII[8]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceII[9]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceII[10]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceII[11]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceII[12]
            
            elif self.YerkeType=="III":
                if self.TypeHR=="B" and self.Decimal in range(1,5) :
                   self.Orbit=sequenceIII[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceIII[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIII[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIII[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIII[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIII[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIII[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIII[7]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIII[8]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIII[9]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceIII[10]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceIII[11]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceIII[12]
                
            elif self.YerkeType=="IV":
                if self.TypeHR=="B" and self.Decimal in range(1,5):
                   self.Orbit=sequenceIV[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceIV[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIV[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIV[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIV[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIV[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceIV[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceIV[7]   
                elif self.TypeHR=="K":
                    self.Orbit=sequenceIV[8]
                    self.Decimal = 0
            
            elif self.YerkeType=="V":
                if self.TypeHR=="B" and self.Decimal in range(1,5):
                   self.Orbit=sequenceV[0]
                elif self.TypeHR=="B" and self.Decimal in range(5,10):
                     self.Orbit=sequenceV[1]   
                elif self.TypeHR=="A" and self.Decimal in range(1,5):
                    self.Orbit=sequenceV[2]
                elif self.TypeHR=="A" and self.Decimal in range(5,10):
                    self.Orbit=sequenceV[3]   
                elif self.TypeHR=="F" and self.Decimal in range(1,5):
                    self.Orbit=sequenceV[4]
                elif self.TypeHR=="F" and self.Decimal in range(5,10):
                    self.Orbit=sequenceV[5]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceV[6]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceV[7]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceV[8]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceV[9]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceV[10]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceV[11]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceV[12]
                
            elif self.YerkeType=="VI":
                if self.TypeHR=="F":
                    self.Decimal = 5
                    self.Orbit=sequenceVI[0]
                elif self.TypeHR=="G" and self.Decimal in range(1,5):
                    self.Orbit=sequenceVI[1]
                elif self.TypeHR=="G" and self.Decimal in range(5,10):
                    self.Orbit=sequenceVI[2]   
                elif self.TypeHR=="K" and self.Decimal in range(1,5):
                    self.Orbit=sequenceVI[3]
                elif self.TypeHR=="K" and self.Decimal in range(5,10):
                    self.Orbit=sequenceVI[4]
                elif self.TypeHR=="M" and self.Decimal in range(1,5):
                     self.Orbit=sequenceVI[5]
                elif self.TypeHR=="M" and self.Decimal in range(5,9):
                    self.Orbit=sequenceVI[6]
                elif self.TypeHR=="M" and self.Decimal==9:
                    self.Orbit=sequenceVI[7]
            
            elif self.YerkeType == "D":
                if self.TypeHR =="B":
                    self.Orbit = sequenceD[0]
                else:
                    self.Orbit = sequenceD[1]
        
        #print(self.YerkeType,self.TypeHR,self.Decimal) en cas de bug
        
        #Etoiles Multinaires
        if EtoileMultinaires==None: 
            potentialmultiplestar = random.randint(1, 6)+random.randint(1, 6)
            if potentialmultiplestar in range(10,12):
                self.EtoileMultinaires="binaire"
            elif potentialmultiplestar == 12:
                self.EtoileMultinaires="Trinaire"
            else:
                self.EtoileMultinaires="Simple"
        else:
            self.EtoileMultinaires=EtoileMultinaires
        

        #Mainworld (planet en zone habitable)
        self.Mainworld = 0
        self.OrbitMainworld = 0
        if Mainworld == None:
            if "H" in self.Orbit:
                self.Mainworld += 1
                self.OrbitMainworld = self.Orbit.index("H")+1
        else:
            self.Mainworld = Mainworld
        
        #NbGazeuse
        self.OrbitGazeuse= [0]
        self.NbGazeuse =0
        if NbGazeuse==None:
            for i in range(0,len(self.Orbit)):
                if self.Orbit[i]=="O":
                    chance = random.randint(1, 6)-2
                    if chance >=1:
                        self.NbGazeuse +=1
                        self.OrbitGazeuse.append(i+1)
            if self.NbGazeuse >0:
                self.OrbitGazeuse.remove(0)
        else:
            self.NbGazeuse = NbGazeuse
        
        # On décide si le Mainworld est une gazeuse ou une planete tellurique
        self.TypeMainworld = "None"
        if self.Mainworld != 0:
            if random.randint(1, 10)!=1: #1/10 chance d'avoir une gazeuse
                self.TypeMainworld = "Tellurique"
            else:
                self.NbGazeuse +=1
                lancedés = random.randint(2, 12)
                if lancedés in range(2,4):
                    self.TypeMainworld = "Gas Dwarf" #3 or more Earth  masses
                elif lancedés in range(4,7):
                    self.TypeMainworld ="Small Gas Giant" #Neptune or Uranus
                elif lancedés in range(7,10):
                    self.TypeMainworld = "Large Gas Giant" #Jupiter or Saturn
                elif lancedés in range(10,12):
                    self.TypeMainworld ="Super jovian" #Up to 12 times Jupiter's mass
                else:
                    self.TypeMainworld = "Brown Dwarf" #At least 13 times more massive than Jupiter
        #NbCeinture
        self.NbCeintures =0
        self.OrbitCeinture = [0]
        if NbCeintures == None:
            chance = random.randint(2,12)
            if self.NbGazeuse != 0:
                chance += 1
            if self.EtoileMultinaires != "Simple":
                chance+=2
            if chance >=12:
                self.NbCeintures += 3
            elif chance <12 and chance >=9:
                self.NbCeintures +=2
            elif chance <9 and chance>= 6:
                self.NbCeintures += 1
            cmpt = self.NbCeintures
            for i in range(0,len(self.Orbit)):
                if self.Orbit[i]=="O" and i+1 not in self.OrbitGazeuse:
                    if cmpt >0 :
                        self.OrbitCeinture.append(i+1)
                        cmpt -=1
            if len(self.OrbitCeinture)>1:
                self.OrbitCeinture.remove(0)
                self.NbCeintures = len(self.OrbitCeinture)
            else:
                self.NbCeintures =0
        else:
            self.NbCeintures = NbCeintures
        
        

        #NbTellurique
        self.NbTellurique = 0
        self.OrbitTellurique = [0]
        if NbTellurique == None:
            for i in range(0,len(self.Orbit)):
                if self.Orbit[i]=="I":
                    self.NbTellurique+=1
                    self.OrbitTellurique.append(i+1)
            if self.NbTellurique >0:
                self.OrbitTellurique.remove(0)
            marge = random.randint(0,3)
            self.NbTellurique += marge
            self.OrbitTellurique.append(marge)

        else:
            self.NbTellurique = NbTellurique

        #Orbit_alpha
        self.Orbit_alpha = []
        ceintures = self.NbCeintures
        for i in range(self.NbTellurique-1):
            booleen = random.randint(0,10)
            if(booleen == 10):
                self.Orbit_alpha.append('B')
                ceintures -= 1
            self.Orbit_alpha.append('T')
            if(self.Orbit[i]=='H' and self.Orbit_alpha[i]=='T'):
                self.Orbit_alpha[i]='M'
        for j in range(self.NbGazeuse):
            booleen = random.randint(0,10)
            if(booleen == 10):
                self.Orbit_alpha.append('B')
                ceintures -= 1
            self.Orbit_alpha.append('G')

# %%
pourcentagegalax = 0

def ParkourSSecteur(tailledés):
    etoiles = []
    pourcentage = 0
    for i in range(1,21):
        for j in range(1,21):
            if random.randint(1,tailledés)==1:
                etoiles.append(Etoile(str(i)+";"+str(j)))
                pourcentage += 1
    print("Pourcentage de",100*(pourcentage/400))
    global pourcentagegalax
    pourcentagegalax += 100*(pourcentage/400)
    return etoiles

taille_region = int(input("Combien de secteurs : \n - "))
nom_region = str(input("Comment voulez vous nommer cette région ?  \n - "))
chemin_fixe = str(input("Renseignez le chemin absolu où est stocké le fichier python"))
nouveau_repertoire = chemin_fixe + nom_region
os.mkdir(nouveau_repertoire)
for i in range(0,taille_region):
    chancesector = random.randint(2, 4)
    list_etoile = ParkourSSecteur(chancesector) #on créé une liste d'étoiles représentant 1 secteur

    data = []
    for etoile in list_etoile:
        data.append({
            'Coordonnees': etoile.coordonnees,
            'TypeHR': etoile.TypeHR,
            'YerkeType': etoile.YerkeType,
            'Decimal': etoile.Decimal,
            'EtoileMultinaires': etoile.EtoileMultinaires,
            'NbTellurique': etoile.NbTellurique,
            'NbGazeuse': etoile.NbGazeuse,
            'NbCeintures': etoile.NbCeintures,
            'Mainworld': etoile.Mainworld,
            'Orbit': etoile.Orbit,
            'Orbit_alpha': etoile.Orbit_alpha
        })
    secteur_df = pd.DataFrame(data)

    # Spécifier le répertoire et le nom du fichier CSV
    fichier_csv = 'Secteur' + str(i) + '.csv'

    # Vérifier si le répertoire existe, sinon le créer
    if not os.path.exists(nouveau_repertoire):
        os.makedirs(nouveau_repertoire)

    # Chemin complet du fichier CSV
    chemin_fichier_csv = os.path.join(nouveau_repertoire, fichier_csv)

    # Enregistrer le DataFrame en tant que fichier CSV
    secteur_df.to_csv(chemin_fichier_csv, index=False)

    print("Le fichier CSV a été créé avec succès.")
# Out:
# Pourcentage de 25.75
# Le fichier CSV a été créé avec succès.
# Pourcentage de 35.5
# Le fichier CSV a été créé avec succès.
